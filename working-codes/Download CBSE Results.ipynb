# %%
import os
# Get cbse results for a roll number
from selenium import webdriver
browser = webdriver.Chrome(executable_path=os.path.join(os.getcwd(),'webdriver','chromedriver.exe'))
browser.get('http://resultsarchives.nic.in/cbseresults/cbseresults2013/class12/cbse122013.htm')

roll = 9199260
for i in range(37):
    field = browser.find_element_by_name('regno')
    field.send_keys(roll)
    field.submit()

    name = browser.find_element_by_css_selector('body > div:nth-child(7) > table:nth-child(2) > tbody > tr:nth-child(2) > td:nth-child(2) > font > b').text
    subject = browser.find_elements_by_css_selector('body > div:nth-child(7) > div > center > table > tbody > tr > td:nth-child(2) > font') #list of all subjects
    mark = browser.find_elements_by_css_selector('body > div:nth-child(7) > div > center > table > tbody > tr > td:nth-child(3) > font') #list of all marks
    # headings = browser.find_element_by_css_selector('body > div:nth-child(7) > div > center > table > tbody > tr:nth-child(1) > td:nth-child(2) > p > font > strong')
    # conclusion = browser.find_element_by_css_selector('body > div:nth-child(7) > div > center > table > tbody > tr:nth-child(10) > td:nth-child(2) > b > font')

    print('Name: '+ name + ' ('+str(roll)+')')
    for i in range(8):
        if str(mark[i].text) == '---':
            continue # breaks this run of the for loop
        print(subject[i].text.title() + ' - ' + str(mark[i].text))

    print('\n-------------\n')
    roll+=1
    browser.find_element_by_css_selector('body > div:nth-child(7) > p:nth-child(5) > b > a > font').click()
# Out:
# Name: ABHINAV KUMAR (9199260)
# Functional English - 096
# Mathematics - 078
# Physics - 085
# Chemistry - 088
# Biology - 092
#
# -------------
#
# Name: ADITI AGARWAL (9199261)
# Functional English - 094
# Psychology - 090
# Physics - 072
# Chemistry - 090
# Biology - 085
#
# -------------
#
# Name: ADITYA A SABU (9199262)
# Functional English - 090
# Physics - 053
# Chemistry - 053
# Biology - 071
# Physical Education - 083
#
# -------------
#
# Name: ADITYA KISHORE JAIN (9199263)
# Functional English - 094
# Mathematics - 080
# Physics - 079
# Chemistry - 077
# Biology - 091
#
# -------------
#
# Name: AISHWARYA (9199264)
# Functional English - 091
# Physics - 056
# Chemistry - 079
# Biology - 076
# Physical Education - 097
#
# -------------
#
# Name: ANAND VARDHAN JAIN (9199265)
# Functional English - 096
# Mathematics - 068
# Physics - 087
# Chemistry - 089
# Biology - 091
#
# -------------
#
# Name: ANURAG DUTTA (9199266)
# Functional English - 094
# Physics - 062
# Chemistry - 061
# Biology - 064
# Physical Education - 091
#
# -------------
#
# Name: APOORVEE SAWHNEY (9199267)
# Functional English - 094
# Psychology - 090
# Physics - 095
# Chemistry - 095
# Biology - 086
#
# -------------
#
# Name: ASHIMA MEHTA (9199268)
# Functional English - 093
# Psychology - 084
# Physics - 083
# Chemistry - 090
# Biology - 088
#
# -------------
#
# Name: DHRUV GARG (9199269)
# Functional English - 087
# Physics - 074
# Chemistry - 073
# Biology - 083
# Physical Education - 089
#
# -------------
#
# Name: DHRUV TALWAR (9199270)
# Functional English - 091
# Physics - 070
# Chemistry - 084
# Biology - 083
# Physical Education - 097
#
# -------------
#
# Name: GAYATRI BHARDWAJ (9199271)
# Functional English - 094
# Physics - 060
# Chemistry - 057
# Biology - 074
# Physical Education - 096
#
# -------------
#
# Name: HASRAT MEHTA (9199272)
# Functional English - 080
# Mathematics - 051
# Physics - 066
# Chemistry - 056
# Biology - 087
#
# -------------
#
# Name: ISHITA SHARMA (9199273)
# Functional English - 091
# Psychology - 083
# Physics - 060
# Chemistry - 075
# Biology - 078
#
# -------------
#
