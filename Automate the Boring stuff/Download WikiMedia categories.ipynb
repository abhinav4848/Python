# %%
import os
os.chdir('D:/Downloads')

# %%
#! python3
# downloadwikimedia.py - Downloads every single image from a category

'''
There are 2 steps this program takes. 
When you enter the category url, it extracts link for all pics' individual pages.
Then from each page it extracts link for full resolution image.
Then it downloads the image.

Along the way, there are 2 try catch blocks.
try:
    download the individual pic's page
    try:
        download the image
    except:
        the image couldn't be downloaded
except:
    pic page not found
'''

import requests, os, bs4

headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36',
    }

url = dirname = ''
errorCount = 0

while url == '' or not url.startswith('https://commons.wikimedia.org/wiki/'):
    # https://commons.wikimedia.org/wiki/Category:St._Paul%27s_School,_Darjeeling
    # https://commons.wikimedia.org/wiki/Commons:Picture_of_the_Year
    url = input('Enter the full url of wikipedia category: ') # starting url

while dirname =='':
    dirname = input('Enter The folder name inside which to download: ')
os.makedirs(dirname, exist_ok=True)   # store comics in ./dirname

# Download the page.
print('Downloading page %s ...' % url)
res = requests.get(url, headers=headers)
res.raise_for_status()

soup = bs4.BeautifulSoup(res.text, 'html.parser')

if url.startswith('https://commons.wikimedia.org/wiki/Category:'):
    picElem = soup.select('li > div > div.gallerytext > a')
else:
    # assume url.startswith('https://commons.wikimedia.org/wiki/'):
    picElem = soup.select('div.thumb > div > a')

if picElem == []:
     print('Could not find any images.')
else:
    for url in picElem:
        picURL= 'https://commons.wikimedia.org/' + url.get('href')
        
        try: 
            res2 = requests.get(picURL, headers=headers)
            res2.raise_for_status()
            soup2 = bs4.BeautifulSoup(res2.text, 'html.parser')
            
            # get id 'first heading', it returns a list, take 0th index, extract contents, remove 'File:' string
            picTitle = soup2.select('#firstHeading')[0].contents[0][5:]
            
            # get url of original file
            originalFile=soup2.select('#mw-content-text > div.fullMedia > p > a')[0].get('href')
            
            if originalFile == []:
                print('Could not find any images.')
            else:
                if os.path.isfile(os.path.join(dirname,picTitle)):
                    # file already exists
                    print(f'{picTitle} already exists in {dirname}')
                    continue
                else:
                    #download the file
                    try:
                        # Download the image.
                        print('Downloading image %s...' % (picTitle))
                        res = requests.get(originalFile)
                        res.raise_for_status()
                    except requests.exceptions.MissingSchema:
                        # start the next iteration of the loop
                        errorCount+=1
                        continue

                    #Save the image to ./dirname
                    imageFile = open(os.path.join(dirname, picTitle), 'wb')
                    for chunk in res.iter_content(100000):
                        imageFile.write(chunk)
                    imageFile.close()
                    
        except requests.exceptions.HTTPError as err:
            print(err)
            errorCount+=1

print('Done. \n\nPics were downloaded to: '+ os.path.join(os.getcwd(), dirname))
if errorCount>0:
    print('There were however, '+str(errorCount)+' error(s) while downloading.')
# Out:
# Enter the full url of wikipedia category: https://commons.wikimedia.org/wiki/Category:St._Paul%27s_School,_Darjeeling
# Enter The folder name inside which to download: st. paul's wikimedia
# Downloading page https://commons.wikimedia.org/wiki/Category:St._Paul%27s_School,_Darjeeling ...
# Downloading image Amitabh Bachchan at St. Paul's School, Darjeeling.jpg...
# Downloading image Bishop Foss Westcott's coffin leaving St. Paul's School, Darjeeling chapel.jpg...
# Downloading image Bishop Foss Westcott.JPG...
# Downloading image Cotton and Milman Halls from Top Field, St. Paul's School, Darjeeling.JPG...
# Downloading image Cotton Hall from Quadrangle side, St. Paul's School, Darjeeling.JPG...
# Downloading image Darjeeling (Baedeker, 1914).jpg...
# Downloading image Darjeeling from above St. Paul's School.jpg...
# Downloading image Flag Staff at the center of Quad at St. Paul's School, Darjeeling.JPG...
# Downloading image Gen. V.K. Singh with the Staff members.jpg...
# Downloading image General Bikram Singh Chief of Army Staff India.jpg...
# Downloading image General view of Darjeeling, showing the Snowy Range, 40 miles distant, as seen from St Paul's School (c. 1870s).jpg...
# Downloading image General view of Darjeeling, showing the Snowy Range, 40 miles distant, as seen from St. Paul's School, Darjeeling.jpg...
# Downloading image Hari Dang and Indira Gandhi, St. Paul's School, Darjeeling.jpg...
# Downloading image Howard Block, St. Paul's School, Darjeeling 01.jpg...
# Downloading image Howard Block, St. Paul's School, Darjeeling 02.jpg...
# Downloading image Howard Block, St. Paul's School, Darjeeling 03.jpg...
# Downloading image Howard Block, St. Paul's School, Darjeeling 04.jpg...
# Downloading image Howard Block, St. Paul's School, Darjeeling 05.jpg...
# Downloading image Induction of the New Rector-St Paul's School Darjeeling.jpg...
# Downloading image List of St. Paul's, Darjeeling Rectors- Till 1974.jpg...
# Downloading image Logo of St Paul's School Darjeeling.jpg...
# Downloading image Main building and Westcott Hall of St. Paul's, Darjeeling.jpg...
# Downloading image Main building of St. Paul's, Darjeeling-2.JPG...
# Downloading image Main building of St. Paul's, Darjeeling.JPG...
# Downloading image Map of Darjeeling in 1914.jpg...
# Downloading image Old Main Gate of St. Paul's School, Darjeeling.jpg...
# Downloading image Panorama of Cotton and Milman Halls from Top Field, SPS Darjeeling.jpg...
# Downloading image Pelly's, HM Residence.jpg...
# Downloading image Rev. D. A Howard shares a light moment with sixth formers on Sports Day..jpg...
# Downloading image School Bell of St. Paul's School, Darjeeling.jpg...
# Downloading image School Chapel, Front View, St. Paul's School, Darjeeling.jpg...
# Downloading image School gate of St. Paul's School, Darjeeling.jpg...
# Downloading image Snowfall- Main Building and Cotton Hall, SPS Darjeeling (Panorama).JPG...
# Downloading image Snowfall- Main Building and Cotton Hall, SPS Darjeeling.JPG...
# Downloading image SPS Pointer.jpeg...
# Downloading image St Pauls School.jpg...
# Downloading image St. Paul's School Dining Hall, 1941.jpg...
# Downloading image St. Paul's School, Darjeeling 175 Years Celebration Souvenir.jpg...
# Downloading image St. Paul's School, Darjeeling Mr Soler 3.jpg...
# Downloading image St. Paul's School, Darjeeling- Flag, modified.jpg...
# Downloading image St. Pauls School, Darjeeling.jpg...
# Downloading image The Chopper landing on the Top Field.jpg...
# Downloading image The St. Paul's School, Darjeeling Crest.jpg...
# Downloading image Westcott Hall Building of St. PAul's School, Darjeeling.jpg...
# Done.
#
# Pics were downloaded to: C:\Users\abhin\Desktop\GitHub\Python\Automate the Boring stuff\st. paul's wikimedia
